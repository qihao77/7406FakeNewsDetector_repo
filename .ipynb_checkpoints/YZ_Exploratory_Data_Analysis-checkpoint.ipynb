# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import nltk
from nltk.corpus import stopwords
from wordcloud import WordCloud
from sklearn.feature_extraction.text import TfidfVectorizer
import gensim
# Out:
# /Users/haoqi/anaconda3/lib/python3.7/site-packages/gensim/similarities/__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
fake = pd.read_csv('Fake.csv')

# %%
real = pd.read_csv('True.csv')

# %% [markdown]
# ### Question 1: How many fake and real news?

# %%
#fake is 1, real is 0
fake['class'] = 1
real['class'] = 0

# %%
data = pd.concat([fake, real], axis=0)

# %%
# Removing the duplicates and preventing problems with indexing
data = data.drop_duplicates()
data = data.reset_index(drop=True)

# %%
# Display the head of data (the first beginning 5 rows)
data.head(5)
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  class
# 0  December 31, 2017      1
# 1  December 31, 2017      1
# 2  December 30, 2017      1
# 3  December 29, 2017      1
# 4  December 25, 2017      1

# %%
fig, ax = plt.subplots(figsize=(4.5,5))
plt.bar(['Fake', 'Real'], data['class'].value_counts(), width=0.4, color='#4B7D95', align='center')
#ax.set_facecolor('#D1D8E2')
for i, v in enumerate(data['class'].value_counts()):
    #print(i, v)
    ax.text(i - 0.11, v + 200,str(v), color='black', fontweight='bold')
ax.set_ylabel('News Counts',size=15)
plt.tight_layout()
plt.show()

# %% [markdown]
# <br>

# %% [markdown]
# ### Question 2: When are the news published?

# %% [markdown]
# **Data cleaning & correction**

# %%
# Correcting some data
data['date'] = data['date'].replace(['19-Feb-18'],'February 19, 2018')
data['date'] = data['date'].replace(['18-Feb-18'],'February 18, 2018')
data['date'] = data['date'].replace(['17-Feb-18'],'February 17, 2018')
data['date'] = data['date'].replace(['16-Feb-18'],'February 16, 2018')
data['date'] = data['date'].replace(['15-Feb-18'],'February 15, 2018')
data['date'] = data['date'].replace(['14-Feb-18'],'February 14, 2018')
data['date'] = data['date'].replace(['13-Feb-18'],'February 13, 2018')


data['date'] = data['date'].str.replace('Dec ', 'December ')
data['date'] = data['date'].str.replace('Nov ', 'November ')
data['date'] = data['date'].str.replace('Oct ', 'October ')
data['date'] = data['date'].str.replace('Sep ', 'September ')
data['date'] = data['date'].str.replace('Aug ', 'August ')
data['date'] = data['date'].str.replace('Jul ', 'July ')
data['date'] = data['date'].str.replace('Jun ', 'June ')
data['date'] = data['date'].str.replace('Apr ', 'April ')
data['date'] = data['date'].str.replace('Mar ', 'March ')
data['date'] = data['date'].str.replace('Feb ', 'February ')
data['date'] = data['date'].str.replace('Jan ', 'January ')

# %% [markdown]
# **Convert the column date to datetime format**

# %%
data['date'] = data['date'].str.replace(' ', '')

# %%
for i, val in enumerate(data['date']):
    data['date'].iloc[i] = pd.to_datetime(data['date'].iloc[i], format='%B%d,%Y', errors='coerce') 

data['date'] = data['date'].astype('datetime64[ns]')
# Out:
# /Users/haoqi/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %% [markdown]
# **Get the date range of all the news pulished**

# %%
print('All news were published from ', min(data['date']).strftime('%Y-%m-%d'),\
     ' to ', max(data['date']).strftime('%Y-%m-%d'))
# Out:
# All news were published from  2015-03-31  to  2018-02-19

# %% [markdown]
# <br>

# %% [markdown]
# ### Question 3: What is the distribution of all news / fake news published over the time range? (by month)

# %% [markdown]
# **Add a new column: "Month" for the sake of future plot purpose**

# %%
import datetime as dt
data['month'] = pd.to_datetime(data['date']).dt.to_period('M')
data['month'] = data['month'].astype(str)

# %%
data.head(5)
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject       date  \
# 0  Donald Trump just couldn t wish all Americans ...    News 2017-12-31
# 1  House Intelligence Committee Chairman Devin Nu...    News 2017-12-31
# 2  On Friday, it was revealed that former Milwauk...    News 2017-12-30
# 3  On Christmas day, Donald Trump announced that ...    News 2017-12-29
# 4  Pope Francis used his annual Christmas Day mes...    News 2017-12-25
#
#    class    month
# 0      1  2017-12
# 1      1  2017-12
# 2      1  2017-12
# 3      1  2017-12
# 4      1  2017-12

# %% [markdown]
# **(1) The distribution of real news published over the time range(by month)**

# %%
sub_realnews = data.loc[data['class']==0]['month'].value_counts()
sub_realnews = sub_realnews.sort_index()
# sub_realnews = sub_realnews.drop("NaT")

# %%
sub_realnews
# Out:
# 2016-01     246
# 2016-02     428
# 2016-03     489
# 2016-04     383
# 2016-05     394
# 2016-06     418
# 2016-07     337
# 2016-08     265
# 2016-09     350
# 2016-10     334
# 2016-11     635
# 2016-12     422
# 2017-01     750
# 2017-02     589
# 2017-03     679
# 2017-04     528
# 2017-05     504
# 2017-06     555
# 2017-07     538
# 2017-08     651
# 2017-09    3062
# 2017-10    3157
# 2017-11    3081
# 2017-12    2416
# Name: month, dtype: int64

# %%
sub_news = data['month'].value_counts()

# %%
plt.figure(figsize=(12,6))
plt.suptitle('Distribution of real news by month')
plt.xticks(rotation=90)
plt.ylabel('Number of real news')
plt.xlabel('Month-Year')
plt.plot(sub_realnews.index, sub_realnews.values, linewidth=2)

# %% [markdown]
# ##### We can see a spike in the distribution of real news in late 2017

# %% [markdown]
# **(2) The distribution of fake news published over the time range(by month)**

# %%
sub_fakenews = data.loc[data['class']==1]['month'].value_counts()
sub_fakenews = sub_fakenews.sort_index()
sub_fakenews = sub_fakenews.drop("NaT")

# %%
sub_fakenews
# Out:
# 2015-03       8
# 2015-04     326
# 2015-05     338
# 2015-06     236
# 2015-07     291
# 2015-08     220
# 2015-09     202
# 2015-10     281
# 2015-11     275
# 2015-12     301
# 2016-01    1081
# 2016-02    1020
# 2016-03    1088
# 2016-04     977
# 2016-05    1012
# 2016-06     871
# 2016-07     883
# 2016-08     892
# 2016-09     936
# 2016-10    1082
# 2016-11    1004
# 2016-12     908
# 2017-01    1029
# 2017-02     879
# 2017-03    1065
# 2017-04     805
# 2017-05     827
# 2017-06     814
# 2017-07     777
# 2017-08     795
# 2017-09     635
# 2017-10     605
# 2017-11     523
# 2017-12     447
# 2018-02      35
# Name: month, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.suptitle('Distribution of fake news by month')
plt.xticks(rotation=90)
plt.ylabel('Number of real news')
plt.xlabel('Month-Year')
plt.plot(sub_fakenews.index, sub_fakenews.values, linewidth=2)

# %% [markdown]
# ##### We can see a spike in the distribution of fake news during 2016

# %%
subreal = sub_realnews.to_frame().rename(columns={'month': 'real'})
subfake = sub_fakenews.to_frame().rename(columns={'month': 'fake'})

# %%
sub = pd.concat([subreal, subfake], join='outer', axis=1).sort_index()

# %%
sub
# Out:
#            real  fake
# 2015-03     NaN     8
# 2015-04     NaN   326
# 2015-05     NaN   338
# 2015-06     NaN   236
# 2015-07     NaN   291
# 2015-08     NaN   220
# 2015-09     NaN   202
# 2015-10     NaN   281
# 2015-11     NaN   275
# 2015-12     NaN   301
# 2016-01   246.0  1081
# 2016-02   428.0  1020
# 2016-03   489.0  1088
# 2016-04   383.0   977
# 2016-05   394.0  1012
# 2016-06   418.0   871
# 2016-07   337.0   883
# 2016-08   265.0   892
# 2016-09   350.0   936
# 2016-10   334.0  1082
# 2016-11   635.0  1004
# 2016-12   422.0   908
# 2017-01   750.0  1029
# 2017-02   589.0   879
# 2017-03   679.0  1065
# 2017-04   528.0   805
# 2017-05   504.0   827
# 2017-06   555.0   814
# 2017-07   538.0   777
# 2017-08   651.0   795
# 2017-09  3062.0   635
# 2017-10  3157.0   605
# 2017-11  3081.0   523
# 2017-12  2416.0   447
# 2018-02     NaN    35

# %%
plt.figure(figsize=(12,6))
plt.suptitle('Distribution of news by month')
plt.xticks(rotation=90)
plt.ylabel('Number of fake news')
plt.xlabel('Month-Year')
plt.plot(sub.index, sub['real'], linewidth=2)
plt.plot(sub.index, sub['fake'], linewidth=2)
plt.legend(['real news','fake news'])
plt.show()

# %% [markdown]
# <br>

# %% [markdown]
# ### Question 4: How long is the news?

# %%
print('The longest news include', max(data['text'].str.len()), 'word/words')
# Out:
# The longest news include 51794 word/words

# %%
print('The shortest news include', min(data['text'].str.len()), 'word/words')
# Out:
# The shortest news include 1 word/words

# %% [markdown]
# <br>

# %% [markdown]
# ### Question 5: Subject Distribution

# %% [markdown]
# #### (1) Subject distribution for Real News Coverage

# %%
sub2_realnews = data.loc[data['class']==0]['subject'].value_counts()
sub2_realnews = sub2_realnews.sort_index()
sub2_realnews
# Out:
# politicsNews    11220
# worldnews        9991
# Name: subject, dtype: int64

# %%
plt.figure(figsize=(6,8))
plt.suptitle('Subject distribution for Real News Coverage')
plt.xticks(rotation=90)
plt.ylabel('Number of real news')
plt.xlabel('Subject')

plt.bar(sub2_realnews.index, height=sub2_realnews.values)
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# #### (2) Subject distribution for Fake News Coverage

# %%
sub2_fakenews = data.loc[data['class']==1]['subject'].value_counts()
sub2_fakenews = sub2_fakenews.sort_index()
sub2_fakenews
# Out:
# Government News    1570
# Middle-east         778
# News               9050
# US_News             783
# left-news          4459
# politics           6838
# Name: subject, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.suptitle('Subject distribution for Fake News Coverage')
plt.xticks(rotation=90)
plt.ylabel('Number of fake news')
plt.xlabel('Subject')

plt.bar(sub2_fakenews.index, height=sub2_fakenews.values)
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# ##### From the barplot above, we can see that fake news are mostly gathered in the subjects as: News, left-news, and politics.
# ##### Whereas the real news are all belong to the subjects as politicsNews and worldnews

# %%
subject_real = sub2_realnews.to_frame().rename(columns={'subject': 'real'})
subject_fake = sub2_fakenews.to_frame().rename(columns={'subject': 'fake'})

# %%
subject = pd.concat([subject_real, subject_fake], join='outer', axis=1).sort_index()

# %%
subject
# Out:
#                     real    fake
# Government News      NaN  1570.0
# Middle-east          NaN   778.0
# News                 NaN  9050.0
# US_News              NaN   783.0
# left-news            NaN  4459.0
# politics             NaN  6838.0
# politicsNews     11220.0     NaN
# worldnews         9991.0     NaN

# %%
plt.figure(figsize=(12,6))
plt.suptitle('Subject distribution for Fake News Coverage')
plt.xticks(rotation=90)
plt.ylabel('Number of fake news')
plt.xlabel('Subject')

plt.bar(subject.index, height=subject['real'])
plt.bar(subject.index, height=subject['fake'])
plt.legend(['real news', 'fake news'])
plt.show()

# %% [markdown]
# <br>

# %% [markdown]
# ### Question 6: What is in the shortest news?

# %%
data[data['text'].str.len() == 1]
# Out:
#                                                    title text       subject  \
# 10922  TAKE OUR POLL: Who Do You Think President Trum...           politics
# 11040  Joe Scarborough BERATES Mika Brzezinski Over “...           politics
# 11189  WATCH TUCKER CARLSON Scorch Sanctuary City May...           politics
# 11224  MAYOR OF SANCTUARY CITY: Trump Trying To Make ...           politics
# 11235  SHOCKER: Public School Turns Computer Lab Into...           politics
# ...                                                  ...  ...           ...
# 21823  FULL VIDEO: THE BLOCKBUSTER INVESTIGATION INTO...          left-news
# 21824  (VIDEO) HILLARY CLINTON: RELIGIOUS BELIEFS MUS...          left-news
# 21854  (VIDEO)ICE PROTECTING OBAMA: WON’T RELEASE NAM...          left-news
# 21870  (VIDEO) HYSTERICAL SNL TAKE ON HILLARY’S ANNOU...          left-news
# 32402                     Graphic: Supreme Court roundup       politicsNews
#
#             date  class    month
# ...

# %%
data[data['text'].str.len() == 1]['class'].value_counts()
# Out:
# 1    626
# 0      1
# Name: class, dtype: int64

# %% [markdown]
# ##### Of all non-text news, only one is real news.

# %% [markdown]
# <BR>

# %% [markdown]
# ### Question 7: How many duplicated titles and text in all news?

# %%
fig, ax = plt.subplots(figsize=(4.5,5))
plt.bar(['Fake', 'Real'], data.loc[data['text'].duplicated() & data['title'].duplicated()]['class'].value_counts(),\
       width=0.4, color='#4B7D95', align='center')
for i, v in enumerate(data.loc[data['text'].duplicated() & data['title'].duplicated()]['class'].value_counts()):
    #print(i, v)
    ax.text(i - 0.08, v + 100,str(v), color='black', fontweight='bold')
ax.set_ylabel('Duplicated News Counts',size=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# <br>

# %% [markdown]
# ### Question 8: Word Cloud Visualization (title)

# %%
stop_words = stopwords.words('english')
stop_words.extend(['from', 'subject', 're', 'edu', 'use'])
def preprocess(text):
    result = []
    for token in gensim.utils.simple_preprocess(text):
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 2 and token not in stop_words:
            result.append(token)
            
    return result

# %% [markdown]
# #### (1) For Fake News

# %%
fake_title = data[data['class'] == 1]['title'].apply(preprocess)
fake_cloud = WordCloud(stopwords = stop_words).generate(" ".join(fake_title.apply(lambda x:" ".join(x))))

# %%
plt.figure(figsize=(12,12))
plt.imshow(fake_cloud, interpolation = 'bilinear')

# %% [markdown]
# #### (2) For Real News

# %%
real_title = data[data['class'] == 0]['title'].apply(preprocess)
real_cloud = WordCloud(stopwords = stop_words).generate(" ".join(real_title.apply(lambda x:" ".join(x))))

# %%
plt.figure(figsize=(12,12))
plt.imshow(real_cloud, interpolation = 'bilinear')

# %% [markdown]
# <br>

# %% [markdown]
# ### Question 9: Word Cloud Visualization (text)

# %% [markdown]
# #### (1) For Fake News

# %%
fake_text = data[data['class'] == 1]['text'].iloc[0:500].apply(preprocess)
fake_cloud2 = WordCloud(stopwords = stop_words).generate(" ".join(fake_text.apply(lambda x:" ".join(x))))

# %%
plt.figure(figsize=(12,12))
plt.imshow(fake_cloud2, interpolation = 'bilinear')

# %% [markdown]
# #### (2) For Real News

# %%
real_text = data[data['class'] == 0]['text'].iloc[0:500].apply(preprocess)
real_cloud2 = WordCloud(stopwords = stop_words).generate(" ".join(real_text.apply(lambda x:" ".join(x))))

# %%
plt.figure(figsize=(12,12))
plt.imshow(real_cloud2, interpolation = 'bilinear')
